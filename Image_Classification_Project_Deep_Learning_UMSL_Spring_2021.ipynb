# %% [markdown]
# <a href="https://colab.research.google.com/github/KatieDionne/UMSL-DL-sp2021.ipynb/blob/main/Image_Classification_Project_Deep_Learning_UMSL_Spring_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PHASE 1**

# %%
from google.colab import files
plantsample = files.upload()
# a subset of my plant photos folder
# Out:
#      <input type="file" id="files-f17d2f1a-918b-4c19-9c70-b9c5e0d0a1b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f17d2f1a-918b-4c19-9c70-b9c5e0d0a1b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving plantsample.zip to plantsample.zip

# %%
! unzip plantsample
# Out:
# Archive:  plantsample.zip
#    creating: plant sample/amarylis/
#   inflating: plant sample/amarylis/IMG_20210221_110136024.jpg
#   inflating: plant sample/amarylis/IMG_20210221_174002224.jpg
#    creating: plant sample/avocado/
#   inflating: plant sample/avocado/IMG_20210214_115804396_HDR.jpg
#   inflating: plant sample/avocado/IMG_20210214_115915768_HDR.jpg
#   inflating: plant sample/avocado/IMG_20210221_105956622.jpg
#   inflating: plant sample/avocado/IMG_20210221_173834658.jpg
#    creating: plant sample/kale/
#   inflating: plant sample/kale/IMG_20210214_120234488_HDR.jpg
#   inflating: plant sample/kale/IMG_20210214_120258424_HDR.jpg
#   inflating: plant sample/kale/IMG_20210219_133503214_HDR.jpg
#   inflating: plant sample/kale/IMG_20210221_104739746_HDR.jpg
#   inflating: plant sample/kale/IMG_20210221_172710049.jpg
#    creating: plant sample/paperwhite/
#   inflating: plant sample/paperwhite/IMG_20210214_120333195_HDR.jpg
# ...

# %%
import PIL
from PIL import Image
zebra1 = Image.open('plant sample/zebra plant/IMG_20210221_174711915.jpg')
print(zebra1.format)
print(zebra1.mode)
print(zebra1.size)
from matplotlib.pyplot import imshow
import numpy as np
# %matplotlib inline
print(np.asarray(zebra1).shape)
imshow(np.asarray(zebra1))
# Out:
# JPEG
# RGB
# (4032, 3024)
# (3024, 4032, 3)

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
snake1 = Image.open('plant sample/snake plant/IMG_20210214_120510537.jpg')
# %matplotlib inline
imshow(np.asarray(snake1))

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
seedling1 = Image.open('plant sample/seedling/IMG_20210221_173130256.jpg')
# %matplotlib inline
imshow(np.asarray(seedling1))

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
pothos1 = Image.open('plant sample/pothos/IMG_20210214_120730066.jpg')
# %matplotlib inline
imshow(np.asarray(pothos1))

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
paperwhite1 = Image.open('plant sample/paperwhite/IMG_20210214_120333195_HDR.jpg')
# %matplotlib inline
imshow(np.asarray(paperwhite1))

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
kale1 = Image.open('plant sample/kale/IMG_20210219_133503214_HDR.jpg')
# %matplotlib inline
imshow(np.asarray(kale1))

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
avocado1 = Image.open('plant sample/avocado/IMG_20210221_105956622.jpg')
# %matplotlib inline
imshow(np.asarray(avocado1))

# %%
import PIL
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
amarylis1 = Image.open('plant sample/amarylis/IMG_20210221_110136024.jpg')
# %matplotlib inline
imshow(np.asarray(amarylis1))

# %% [markdown]
# **PHASE 2**

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255)
generator = datagen.flow_from_directory(
    plantphotos,  # name of target directory
    target_size=(150,150),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9087ebe140f9> in <module>()
#       2 datagen = ImageDataGenerator(rescale=1./255)
#       3 generator = datagen.flow_from_directory(
# ----> 4     plantphotos,
#       5     target_size=(150,150),
#       6     batch_size=20,
#
# NameError: name 'plantphotos' is not defined
